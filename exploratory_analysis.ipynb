# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Datasets/sales_data.csv")

# %%
df
# Out:
#             Date   Product Region  Sales  Customer_Age Customer_Gender  \
# 0     2022-01-01  Widget C  South    786            26            Male
# 1     2022-01-02  Widget D   East    850            29            Male
# 2     2022-01-03  Widget A  North    871            40          Female
# 3     2022-01-04  Widget C  South    464            31            Male
# 4     2022-01-05  Widget C  South    262            50          Female
# ...          ...       ...    ...    ...           ...             ...
# 2495  2028-10-31  Widget D  North    979            57            Male
# 2496  2028-11-01  Widget D  South    858            30          Female
# 2497  2028-11-02  Widget B   East    878            21          Female
# 2498  2028-11-03  Widget C  South    862            63            Male
# 2499  2028-11-04  Widget D   West    614            31            Male
#
#       Customer_Satisfaction
# 0                  2.874407
# 1                  3.365205
# 2                  4.547364
# 3                  4.555420
# 4                  3.982935
# ...                     ...
# 2495               3.525510
# 2496               3.386064
# 2497               2.272609
# 2498               2.805692
# 2499               1.987853
#
# [2500 rows x 7 columns]

# %%
# Convert Date to datetime
df["Date"] = pd.to_datetime(df["Date"])

# Extract time components
df["Year"] = df["Date"].dt.year
df["Month"] = df["Date"].dt.month
df["Quarter"] = df["Date"].dt.quarter

# Monthly sales performance
monthly_sales = df.groupby(["Year", "Month"])["Sales"].sum().reset_index()

# Quarterly sales performance
quarterly_sales = df.groupby(["Year", "Quarter"])["Sales"].sum().reset_index()

# Annual sales performance
yearly_sales = df.groupby("Year")["Sales"].sum().reset_index()

# Sales trend over time (resampled by month)
time_series = df.set_index("Date").resample("M")["Sales"].sum()

# Plot monthly sales trend
plt.figure(figsize=(12, 6))
time_series.plot()
plt.title('Monthly Sales Trend')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.grid(True)
plt.tight_layout()
# Out:
# /var/folders/xj/3_lm772934v8l4mss_kx_h1w0000gn/T/ipykernel_72837/3983718107.py:19: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   time_series = df.set_index('Date').resample('M')['Sales'].sum()
